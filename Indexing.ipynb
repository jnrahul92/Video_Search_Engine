# %%
import os
import nltk

# %%
import pickle

# %%
transcription_dir = r"D:\M Tech DSE Bits\Semester 3\Information Retrieval\Assignments\Assignment 2\Transcription\\"
ocr_dir = r"D:\M Tech DSE Bits\Semester 3\Information Retrieval\Assignments\Assignment 2\OCR Data\\"

# %%
video_dir = r"D:\M Tech DSE Bits\Semester 3\Information Retrieval\Assignments\Assignment 2\Data\\"

# %%
stopwords = nltk.corpus.stopwords.words("english")

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

# %%
vocab_dict = {}

# %%
for file in os.listdir(ocr_dir):
    with open(ocr_dir + file, encoding="utf-8") as f:
        lines = f.readlines()
        f.close()
    with open(transcription_dir + file, encoding="utf-8") as f:
        lines2 = f.readlines()
        lines.extend(lines2)
        f.close()
    lines = " ".join(lines)
    tokens = tokenizer.tokenize(lines)
    tokens = [w for w in tokens if w not in stopwords]
    tokens = list(set(tokens))
    hash_file = hashlib.md5(file.encode()).hexdigest()
    for t in tokens:
        try:
            vocab_dict[t.lower()].extend([file])
        except:
            vocab_dict[t.lower()] = [file]

# %%
with open("index.pkl", "wb") as f:
    pickle.dump(vocab_dict, f)

# %%
with open("index.pkl", "rb") as f:
    loaded_dict = pickle.load(f)

# %%
loaded_dict
# Out:
# {'translation': ['Applications of RNNs.txt', 'Applications of RNNs.txt'],
#  'brown': ['Applications of RNNs.txt'],
#  '_': ['Applications of RNNs.txt', 'Cost Function for RNNs.txt'],
#  'include': ['Applications of RNNs.txt'],
#  'jw_jw': ['Applications of RNNs.txt'],
#  'analysis': ['Applications of RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt'],
#  '4': ['Applications of RNNs.txt',
#   'Math In Simple RNNs.txt',
#   'Traditional Language Models.txt',
#   'Trax Neural Networks.txt'],
#  'generation': ['Applications of RNNs.txt'],
#  'tweet': ['Applications of RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt'],
#  'summary': ['Applications of RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Recurrent Neural Networks.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  'real': ['Applications of RNNs.txt'],
#  'faim': ['Applications of RNNs.txt'],
#  'fw': ['Applications of RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Math In Simple RNNs.txt'],
#  '1': ['Applications of RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Recurrent Neural Networks.txt',
#   'Serial Layer.txt',
#   'Traditional Language Models.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  'h': ['Applications of RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Math In Simple RNNs.txt'],
#  'en': ['Applications of RNNs.txt'],
#  'implemented': ['Applications of RNNs.txt'],
#  'jwjw': ['Applications of RNNs.txt'],
#  'decoder': ['Applications of RNNs.txt'],
#  'tasks': ['Applications of RNNs.txt'],
#  '6': ['Applications of RNNs.txt',
#   'Classes, Subclasses and Inheritance.txt',
#   'Math In Simple RNNs.txt',
#   'Traditional Language Models.txt'],
#  'fwfwfwfwfw': ['Applications of RNNs.txt'],
#  'caption': ['Applications of RNNs.txt', 'Applications of RNNs.txt'],
#  'valladolid': ['Applications of RNNs.txt'],
#  'św': ['Applications of RNNs.txt'],
#  'fwfwfw': ['Applications of RNNs.txt'],
#  'sw': ['Applications of RNNs.txt'],
#  'variety': ['Applications of RNNs.txt'],
#  'positive': ['Applications of RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt'],
#  'applications': ['Applications of RNNs.txt'],
#  'a': ['Applications of RNNs.txt',
#   'Math In Simple RNNs.txt',
#   'Traditional Language Models.txt'],
#  'hungry': ['Applications of RNNs.txt'],
#  '01': ['Applications of RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Trax Neural Networks.txt'],
#  'x': ['Applications of RNNs.txt',
#   'Classes, Subclasses and Inheritance.txt',
#   'Cost Function for RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Training.txt'],
#  'puppy': ['Applications of RNNs.txt'],
#  'encoder': ['Applications of RNNs.txt'],
#  'ai': ['Applications of RNNs.txt',
#   'Classes, Subclasses and Inheritance.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Recurrent Neural Networks.txt',
#   'Serial Layer.txt',
#   'Traditional Language Models.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  'machine': ['Applications of RNNs.txt'],
#  'happy': ['Applications of RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt'],
#  'ïwjw': ['Applications of RNNs.txt'],
#  'rnns': ['Applications of RNNs.txt',
#   'Applications of RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Math In Simple RNNs.txt',
#   'Math In Simple RNNs.txt',
#   'Recurrent Neural Networks.txt'],
#  'many': ['Applications of RNNs.txt'],
#  'o': ['Applications of RNNs.txt',
#   'Classes, Subclasses and Inheritance.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Recurrent Neural Networks.txt',
#   'Serial Layer.txt',
#   'Traditional Language Models.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  'jwfw': ['Applications of RNNs.txt'],
#  'j': ['Applications of RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Traditional Language Models.txt',
#   'Trax Neural Networks.txt'],
#  'sentiment': ['Applications of RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt'],
#  'w': ['Applications of RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Recurrent Neural Networks.txt',
#   'Serial Layer.txt',
#   'Traditional Language Models.txt',
#   'Traditional Language Models.txt',
#   'Trax Neural Networks.txt',
#   'Trax Neural Networks.txt'],
#  'laliga': ['Applications of RNNs.txt'],
#  'atletico': ['Applications of RNNs.txt'],
#  'one': ['Applications of RNNs.txt', 'Training.txt'],
#  'fr': ['Applications of RNNs.txt'],
#  'deeplearning': ['Applications of RNNs.txt',
#   'Classes, Subclasses and Inheritance.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Recurrent Neural Networks.txt',
#   'Serial Layer.txt',
#   'Traditional Language Models.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  'zaragoza': ['Applications of RNNs.txt'],
#  'nlp': ['Applications of RNNs.txt', 'Other Layers.txt'],
#  'fwfw': ['Applications of RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Math In Simple RNNs.txt'],
#  'madrid': ['Applications of RNNs.txt'],
#  '0': ['Applications of RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Traditional Language Models.txt'],
#  'santander': ['Applications of RNNs.txt'],
#  'peak': ['Classes, Subclasses and Inheritance.txt'],
#  'r': ['Classes, Subclasses and Inheritance.txt', 'Other Layers.txt'],
#  'parameters': ['Classes, Subclasses and Inheritance.txt',
#   'Classes, Subclasses and Inheritance.txt',
#   'Dense And Relu Layers.txt',
#   'Other Layers.txt',
#   'Recurrent Neural Networks.txt'],
#  'methods': ['Classes, Subclasses and Inheritance.txt',
#   'Classes, Subclasses and Inheritance.txt'],
#  'my_method': ['Classes, Subclasses and Inheritance.txt'],
#  'return': ['Classes, Subclasses and Inheritance.txt', 'Training.txt'],
#  'blue': ['Classes, Subclasses and Inheritance.txt'],
#  'outline': ['Classes, Subclasses and Inheritance.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  'classes': ['Classes, Subclasses and Inheritance.txt',
#   'Classes, Subclasses and Inheritance.txt',
#   'Cost Function for RNNs.txt'],
#  '8': ['Classes, Subclasses and Inheritance.txt',
#   'Other Layers.txt',
#   'Training.txt'],
#  '145': ['Classes, Subclasses and Inheritance.txt'],
#  'method': ['Classes, Subclasses and Inheritance.txt'],
#  'length': ['Classes, Subclasses and Inheritance.txt'],
#  'box': ['Classes, Subclasses and Inheritance.txt'],
#  'magenta': ['Classes, Subclasses and Inheritance.txt'],
#  '52': ['Classes, Subclasses and Inheritance.txt'],
#  'how': ['Classes, Subclasses and Inheritance.txt', 'Math In Simple RNNs.txt'],
#  'inheritance': ['Classes, Subclasses and Inheritance.txt',
#   'Classes, Subclasses and Inheritance.txt'],
#  'animal': ['Classes, Subclasses and Inheritance.txt'],
#  '56': ['Classes, Subclasses and Inheritance.txt'],
#  'name': ['Classes, Subclasses and Inheritance.txt'],
#  'litter': ['Classes, Subclasses and Inheritance.txt'],
#  'common': ['Classes, Subclasses and Inheritance.txt'],
#  '61': ['Classes, Subclasses and Inheritance.txt'],
#  '77': ['Classes, Subclasses and Inheritance.txt'],
#  '10': ['Classes, Subclasses and Inheritance.txt',
#   'Dense And Relu Layers.txt'],
#  'g': ['Classes, Subclasses and Inheritance.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Training.txt'],
#  '121': ['Classes, Subclasses and Inheritance.txt'],
#  '133': ['Classes, Subclasses and Inheritance.txt'],
#  'subclass': ['Classes, Subclasses and Inheritance.txt'],
#  'print': ['Classes, Subclasses and Inheritance.txt'],
#  'self': ['Classes, Subclasses and Inheritance.txt'],
#  'b': ['Classes, Subclasses and Inheritance.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt'],
#  'def': ['Classes, Subclasses and Inheritance.txt', 'Training.txt'],
#  'class': ['Classes, Subclasses and Inheritance.txt',
#   'Classes, Subclasses and Inheritance.txt'],
#  'orange': ['Classes, Subclasses and Inheritance.txt'],
#  'convenient': ['Classes, Subclasses and Inheritance.txt'],
#  '3': ['Classes, Subclasses and Inheritance.txt',
#   'Cost Function for RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Serial Layer.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  'weight': ['Classes, Subclasses and Inheritance.txt'],
#  'myclass': ['Classes, Subclasses and Inheritance.txt'],
#  '_call_': ['Classes, Subclasses and Inheritance.txt'],
#  'inheritence': ['Classes, Subclasses and Inheritance.txt'],
#  'height': ['Classes, Subclasses and Inheritance.txt'],
#  'implementation': ['Classes, Subclasses and Inheritance.txt'],
#  'python': ['Classes, Subclasses and Inheritance.txt'],
#  'subclasses': ['Classes, Subclasses and Inheritance.txt'],
#  'work': ['Classes, Subclasses and Inheritance.txt'],
#  '198': ['Classes, Subclasses and Inheritance.txt'],
#  'domestic': ['Classes, Subclasses and Inheritance.txt'],
#  '7': ['Classes, Subclasses and Inheritance.txt',
#   'Dense And Relu Layers.txt',
#   'Other Layers.txt'],
#  'f': ['Classes, Subclasses and Inheritance.txt', 'Training.txt'],
#  'color': ['Classes, Subclasses and Inheritance.txt'],
#  '2': ['Classes, Subclasses and Inheritance.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Serial Layer.txt',
#   'Traditional Language Models.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  'definit_': ['Classes, Subclasses and Inheritance.txt'],
#  'go': ['Classes, Subclasses and Inheritance.txt'],
#  'share': ['Classes, Subclasses and Inheritance.txt',
#   'Recurrent Neural Networks.txt'],
#  '166': ['Classes, Subclasses and Inheritance.txt'],
#  '230': ['Classes, Subclasses and Inheritance.txt'],
#  '31': ['Cost Function for RNNs.txt'],
#  '₁': ['Cost Function for RNNs.txt',
#   'Math In Simple RNNs.txt',
#   'Traditional Language Models.txt'],
#  'k': ['Cost Function for RNNs.txt'],
#  'ý2': ['Cost Function for RNNs.txt'],
#  'example': ['Cost Function for RNNs.txt'],
#  '41': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  'respect': ['Cost Function for RNNs.txt'],
#  'wh': ['Cost Function for RNNs.txt',
#   'Math In Simple RNNs.txt',
#   'Recurrent Neural Networks.txt'],
#  'σy': ['Cost Function for RNNs.txt'],
#  'function': ['Cost Function for RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Dense And Relu Layers.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  't₁': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  '¹': ['Cost Function for RNNs.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt'],
#  '1089': ['Cost Function for RNNs.txt'],
#  't₂': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  'logâj': ['Cost Function for RNNs.txt'],
#  'i': ['Cost Function for RNNs.txt',
#   'Math In Simple RNNs.txt',
#   'Other Layers.txt',
#   'Recurrent Neural Networks.txt',
#   'Traditional Language Models.txt'],
#  'logist': ['Cost Function for RNNs.txt'],
#  'σ': ['Cost Function for RNNs.txt'],
#  'co': ['Cost Function for RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt'],
#  'average': ['Cost Function for RNNs.txt', 'Cost Function for RNNs.txt'],
#  '5': ['Cost Function for RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Traditional Language Models.txt'],
#  'c1': ['Cost Function for RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt'],
#  'yt': ['Cost Function for RNNs.txt'],
#  'bn': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  'lyft': ['Cost Function for RNNs.txt'],
#  'ÿ¹': ['Cost Function for RNNs.txt'],
#  '¹1': ['Cost Function for RNNs.txt'],
#  'possibilities': ['Cost Function for RNNs.txt'],
#  'for': ['Cost Function for RNNs.txt'],
#  'xn²': ['Cost Function for RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt'],
#  '₂': ['Cost Function for RNNs.txt', 'Traditional Language Models.txt'],
#  'log': ['Cost Function for RNNs.txt'],
#  'single': ['Cost Function for RNNs.txt'],
#  'gti': ['Cost Function for RNNs.txt'],
#  'wyhh': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  '5t': ['Cost Function for RNNs.txt'],
#  'time': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  't2': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  'h₂': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  'either': ['Cost Function for RNNs.txt'],
#  'e': ['Cost Function for RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Traditional Language Models.txt'],
#  'histe': ['Cost Function for RNNs.txt'],
#  'x2': ['Cost Function for RNNs.txt',
#   'Cost Function for RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt',
#   'Trax Neural Networks.txt'],
#  'h₁': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  'cross': ['Cost Function for RNNs.txt'],
#  'oy1': ['Cost Function for RNNs.txt'],
#  'looking': ['Cost Function for RNNs.txt'],
#  'entropy': ['Cost Function for RNNs.txt'],
#  'σσu¹': ['Cost Function for RNNs.txt'],
#  'logửj': ['Cost Function for RNNs.txt'],
#  'yj': ['Cost Function for RNNs.txt'],
#  'logy': ['Cost Function for RNNs.txt'],
#  'x1': ['Cost Function for RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt'],
#  'loss': ['Cost Function for RNNs.txt', 'Cost Function for RNNs.txt'],
#  'σς': ['Cost Function for RNNs.txt'],
#  'ŷ': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  '10895': ['Cost Function for RNNs.txt'],
#  't': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  'σσyt': ['Cost Function for RNNs.txt'],
#  'ý': ['Cost Function for RNNs.txt',
#   'Math In Simple RNNs.txt',
#   'Math In Simple RNNs.txt'],
#  'tk': ['Cost Function for RNNs.txt'],
#  'ý3': ['Cost Function for RNNs.txt'],
#  'ŷj': ['Cost Function for RNNs.txt'],
#  '²4': ['Cost Function for RNNs.txt'],
#  '₁x': ['Cost Function for RNNs.txt'],
#  't1': ['Cost Function for RNNs.txt',
#   'Math In Simple RNNs.txt',
#   'Trax Neural Networks.txt'],
#  'σσy': ['Cost Function for RNNs.txt'],
#  'cost': ['Cost Function for RNNs.txt'],
#  'tr': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  'bh': ['Cost Function for RNNs.txt', 'Math In Simple RNNs.txt'],
#  'хо': ['Cost Function for RNNs.txt',
#   'Neural Network for Sentiment Analysis.txt'],
#  'max': ['Dense And Relu Layers.txt'],
#  '03': ['Dense And Relu Layers.txt'],
#  'laye': ['Dense And Relu Layers.txt'],
#  '02': ['Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt'],
#  '23': ['Dense And Relu Layers.txt'],
#  'zi¹': ['Dense And Relu Layers.txt'],
#  'layer': ['Dense And Relu Layers.txt',
#   'Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Other Layers.txt',
#   'Serial Layer.txt'],
#  'layers': ['Dense And Relu Layers.txt',
#   'Other Layers.txt',
#   'Serial Layer.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt'],
#  'unit': ['Dense And Relu Layers.txt', 'Trax Neural Networks.txt'],
#  'dense': ['Dense And Relu Layers.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt'],
#  'dot': ['Dense And Relu Layers.txt', 'Trax Neural Networks.txt'],
#  '2¹': ['Dense And Relu Layers.txt'],
#  'gli': ['Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Trax Neural Networks.txt'],
#  'med': ['Dense And Relu Layers.txt'],
#  '241af': ['Dense And Relu Layers.txt'],
#  'الله': ['Dense And Relu Layers.txt'],
#  'z₁a₁': ['Dense And Relu Layers.txt'],
#  'non': ['Dense And Relu Layers.txt', 'Trax Neural Networks.txt'],
#  'g¹¹': ['Dense And Relu Layers.txt'],
#  '0₁': ['Dense And Relu Layers.txt'],
#  '²': ['Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt'],
#  'zli': ['Dense And Relu Layers.txt'],
#  'd': ['Dense And Relu Layers.txt'],
#  'aversch': ['Dense And Relu Layers.txt'],
#  'joe': ['Dense And Relu Layers.txt'],
#  'live': ['Dense And Relu Layers.txt'],
#  'whir': ['Dense And Relu Layers.txt'],
#  'linear': ['Dense And Relu Layers.txt',
#   'Dense And Relu Layers.txt',
#   'Trax Neural Networks.txt'],
#  'af': ['Dense And Relu Layers.txt'],
#  'zlil': ['Dense And Relu Layers.txt'],
#  'ij': ['Dense And Relu Layers.txt'],
#  'networks': ['Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Recurrent Neural Networks.txt',
#   'Trax Neural Networks.txt',
#   'Trax Neural Networks.txt'],
#  'لا': ['Dense And Relu Layers.txt'],
#  'il': ['Dense And Relu Layers.txt', 'Trax Neural Networks.txt'],
#  '20': ['Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt'],
#  'gl¹¹': ['Dense And Relu Layers.txt'],
#  'of': ['Dense And Relu Layers.txt'],
#  'rectified': ['Dense And Relu Layers.txt'],
#  '2₁': ['Dense And Relu Layers.txt'],
#  'gl¹': ['Dense And Relu Layers.txt'],
#  '2₁a₁': ['Dense And Relu Layers.txt'],
#  'dy': ['Dense And Relu Layers.txt'],
#  'layen': ['Dense And Relu Layers.txt'],
#  'product': ['Dense And Relu Layers.txt', 'Trax Neural Networks.txt'],
#  'whi': ['Dense And Relu Layers.txt',
#   'Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt'],
#  'z': ['Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Trax Neural Networks.txt'],
#  'derise': ['Dense And Relu Layers.txt'],
#  'de': ['Dense And Relu Layers.txt', 'Traditional Language Models.txt'],
#  'trainable': ['Dense And Relu Layers.txt',
#   'Other Layers.txt',
#   'Other Layers.txt'],
#  'al': ['Dense And Relu Layers.txt'],
#  'g¹': ['Dense And Relu Layers.txt'],
#  'ali': ['Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Trax Neural Networks.txt'],
#  'relu': ['Dense And Relu Layers.txt', 'Dense And Relu Layers.txt'],
#  '24': ['Dense And Relu Layers.txt', 'Trax Neural Networks.txt'],
#  'او': ['Dense And Relu Layers.txt'],
#  '22': ['Dense And Relu Layers.txt'],
#  '2₁ai': ['Dense And Relu Layers.txt'],
#  '00': ['Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt'],
#  'jo': ['Dense And Relu Layers.txt'],
#  'hidden': ['Dense And Relu Layers.txt',
#   'Math In Simple RNNs.txt',
#   'Trax Neural Networks.txt'],
#  'wali': ['Dense And Relu Layers.txt'],
#  'whit': ['Dense And Relu Layers.txt', 'Dense And Relu Layers.txt'],
#  'detail': ['Dense And Relu Layers.txt'],
#  'gli¹': ['Dense And Relu Layers.txt'],
#  'trax': ['Dense And Relu Layers.txt',
#   'Training.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt',
#   'Trax Neural Networks.txt'],
#  'neural': ['Dense And Relu Layers.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Recurrent Neural Networks.txt',
#   'Trax Neural Networks.txt',
#   'Trax Neural Networks.txt'],
#  'gm¹¹': ['Dense And Relu Layers.txt'],
#  'tali': ['Dense And Relu Layers.txt'],
#  'v': ['Dense And Relu Layers.txt'],
#  'denise': ['Dense And Relu Layers.txt'],
#  'achs': ['Math In Simple RNNs.txt'],
#  'kk': ['Math In Simple RNNs.txt'],
#  '¹3': ['Math In Simple RNNs.txt'],
#  'make': ['Math In Simple RNNs.txt'],
#  'lang': ['Math In Simple RNNs.txt'],
#  'p': ['Math In Simple RNNs.txt', 'Traditional Language Models.txt'],
#  'n': ['Math In Simple RNNs.txt',
#   'Traditional Language Models.txt',
#   'Trax Neural Networks.txt'],
#  'propagate': ['Math In Simple RNNs.txt'],
#  'whz': ['Math In Simple RNNs.txt'],
#  'bp': ['Math In Simple RNNs.txt'],
#  '¹₂': ['Math In Simple RNNs.txt'],
#  'whart': ['Math In Simple RNNs.txt'],
#  'whs': ['Math In Simple RNNs.txt'],
#  'two': ['Math In Simple RNNs.txt'],
#  'through': ['Math In Simple RNNs.txt'],
#  '12': ['Math In Simple RNNs.txt'],
#  'hcp': ['Math In Simple RNNs.txt'],
#  'lo': ['Math In Simple RNNs.txt'],
#  'st': ['Math In Simple RNNs.txt'],
#  'basic': ['Math In Simple RNNs.txt',
#   'Recurrent Neural Networks.txt',
#   'Trax Neural Networks.txt'],
#  'vanilla': ['Math In Simple RNNs.txt'],
#  'recurrent': ['Math In Simple RNNs.txt', 'Recurrent Neural Networks.txt'],
#  'yh': ['Math In Simple RNNs.txt'],
#  'l': ['Math In Simple RNNs.txt'],
#  'winh': ['Math In Simple RNNs.txt'],
#  'whax': ['Math In Simple RNNs.txt'],
#  'ash': ['Math In Simple RNNs.txt'],
#  'states': ['Math In Simple RNNs.txt'],
#  'predictions': ['Math In Simple RNNs.txt'],
#  'ats': ['Math In Simple RNNs.txt'],
#  'astx': ['Math In Simple RNNs.txt'],
#  'licha': ['Math In Simple RNNs.txt'],
#  'te': ['Math In Simple RNNs.txt', 'Trax Neural Networks.txt'],
#  'whe': ['Math In Simple RNNs.txt'],
#  'liste': ['Math In Simple RNNs.txt'],
#  'with': ['Math In Simple RNNs.txt'],
#  'whhh': ['Math In Simple RNNs.txt'],
#  'kfw': ['Math In Simple RNNs.txt'],
#  'astis': ['Math In Simple RNNs.txt'],
#  'what': ['Math In Simple RNNs.txt'],
#  'ø': ['Math In Simple RNNs.txt'],
#  'whh': ['Math In Simple RNNs.txt'],
#  'h1': ['Math In Simple RNNs.txt'],
#  'w₁₂x': ['Math In Simple RNNs.txt'],
#  'inputs': ['Math In Simple RNNs.txt'],
#  'rnn': ['Math In Simple RNNs.txt'],
#  'wynh': ['Math In Simple RNNs.txt'],
#  'fwle': ['Math In Simple RNNs.txt'],
#  '9': ['Math In Simple RNNs.txt', 'Traditional Language Models.txt'],
#  'wahh¹': ['Math In Simple RNNs.txt'],
#  'whxx': ['Math In Simple RNNs.txt'],
#  'information': ['Math In Simple RNNs.txt'],
#  'math': ['Math In Simple RNNs.txt', 'Training.txt'],
#  'whis': ['Math In Simple RNNs.txt'],
#  'gwh': ['Math In Simple RNNs.txt'],
#  'whili': ['Math In Simple RNNs.txt'],
#  'asha': ['Math In Simple RNNs.txt'],
#  'gwhhh': ['Math In Simple RNNs.txt'],
#  'wie': ['Math In Simple RNNs.txt'],
#  'b₁': ['Math In Simple RNNs.txt'],
#  'whare': ['Math In Simple RNNs.txt'],
#  'se': ['Math In Simple RNNs.txt'],
#  'fwlew': ['Math In Simple RNNs.txt'],
#  'ashx': ['Math In Simple RNNs.txt'],
#  'ŷt': ['Math In Simple RNNs.txt'],
#  'units': ['Math In Simple RNNs.txt'],
#  'simple': ['Math In Simple RNNs.txt'],
#  'gisha': ['Math In Simple RNNs.txt'],
#  '615': ['Neural Network for Sentiment Analysis.txt'],
#  'movie': ['Neural Network for Sentiment Analysis.txt'],
#  'wilali': ['Neural Network for Sentiment Analysis.txt'],
#  'forward': ['Neural Network for Sentiment Analysis.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Training.txt',
#   'Training.txt'],
#  'longest': ['Neural Network for Sentiment Analysis.txt'],
#  'embedding': ['Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Other Layers.txt'],
#  'initial': ['Neural Network for Sentiment Analysis.txt'],
#  'ith': ['Neural Network for Sentiment Analysis.txt'],
#  'xo': ['Neural Network for Sentiment Analysis.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt'],
#  'this': ['Neural Network for Sentiment Analysis.txt'],
#  '621': ['Neural Network for Sentiment Analysis.txt'],
#  '700': ['Neural Network for Sentiment Analysis.txt'],
#  'tweets': ['Neural Network for Sentiment Analysis.txt'],
#  '1000': ['Neural Network for Sentiment Analysis.txt'],
#  'representation': ['Neural Network for Sentiment Analysis.txt',
#   'Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt'],
#  'to': ['Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt'],
#  'number': ['Neural Network for Sentiment Analysis.txt'],
#  'word': ['Neural Network for Sentiment Analysis.txt',
#   'Other Layers.txt',
#   'Recurrent Neural Networks.txt'],
#  'in²': ['Neural Network for Sentiment Analysis.txt',
#   'Trax Neural Networks.txt'],
#  '720': ['Neural Network for Sentiment Analysis.txt'],
#  '⁰': ['Neural Network for Sentiment Analysis.txt'],
#  '680': ['Neural Network for Sentiment Analysis.txt'],
#  'classify': ['Neural Network for Sentiment Analysis.txt'],
#  'padding': ['Neural Network for Sentiment Analysis.txt'],
#  'alo': ['Neural Network for Sentiment Analysis.txt'],
#  'in': ['Neural Network for Sentiment Analysis.txt',
#   'Recurrent Neural Networks.txt',
#   'Serial Layer.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  'activations': ['Neural Network for Sentiment Analysis.txt'],
#  'xn': ['Neural Network for Sentiment Analysis.txt',
#   'Trax Neural Networks.txt'],
#  'match': ['Neural Network for Sentiment Analysis.txt',
#   'Traditional Language Models.txt'],
#  'good': ['Neural Network for Sentiment Analysis.txt'],
#  '55': ['Neural Network for Sentiment Analysis.txt'],
#  'propagation': ['Neural Network for Sentiment Analysis.txt',
#   'Serial Layer.txt',
#   'Training.txt'],
#  'hand': ['Neural Network for Sentiment Analysis.txt'],
#  'size': ['Neural Network for Sentiment Analysis.txt'],
#  'χη': ['Neural Network for Sentiment Analysis.txt'],
#  'zebra': ['Neural Network for Sentiment Analysis.txt'],
#  'negative': ['Neural Network for Sentiment Analysis.txt'],
#  'aviesom': ['Neural Network for Sentiment Analysis.txt'],
#  'complex': ['Neural Network for Sentiment Analysis.txt'],
#  'able': ['Neural Network for Sentiment Analysis.txt'],
#  '550': ['Neural Network for Sentiment Analysis.txt'],
#  'almost': ['Neural Network for Sentiment Analysis.txt'],
#  'structure': ['Neural Network for Sentiment Analysis.txt',
#   'Recurrent Neural Networks.txt'],
#  'law': ['Other Layers.txt'],
#  '040': ['Other Layers.txt'],
#  '018': ['Other Layers.txt'],
#  'other': ['Other Layers.txt'],
#  '456780': ['Other Layers.txt'],
#  'mvlt': ['Other Layers.txt'],
#  'vii': ['Other Layers.txt'],
#  'using': ['Other Layers.txt', 'Training.txt', 'Trax Neural Networks.txt'],
#  'ī': ['Other Layers.txt'],
#  '011': ['Other Layers.txt'],
#  '456': ['Other Layers.txt'],
#  '022': ['Other Layers.txt'],
#  'mean': ['Other Layers.txt'],
#  '80': ['Other Layers.txt'],
#  '020': ['Other Layers.txt'],
#  '009': ['Other Layers.txt'],
#  '45600': ['Other Layers.txt'],
#  '2345678': ['Other Layers.txt'],
#  'la': ['Other Layers.txt'],
#  'c': ['Other Layers.txt', 'Trax Neural Networks.txt'],
#  'weights': ['Other Layers.txt', 'Training.txt'],
#  'embeddings': ['Other Layers.txt'],
#  '050': ['Other Layers.txt'],
#  'ot': ['Other Layers.txt'],
#  'sad': ['Other Layers.txt'],
#  'ther': ['Other Layers.txt'],
#  '010': ['Other Layers.txt'],
#  '001': ['Other Layers.txt'],
#  'gives': ['Other Layers.txt'],
#  '45678': ['Other Layers.txt'],
#  '006': ['Other Layers.txt'],
#  'vocabulary': ['Other Layers.txt'],
#  '044': ['Other Layers.txt'],
#  '047': ['Other Layers.txt'],
#  'vector': ['Other Layers.txt'],
#  'pers': ['Other Layers.txt'],
#  '003': ['Other Layers.txt'],
#  'no': ['Other Layers.txt'],
#  '45680': ['Other Layers.txt'],
#  'index': ['Other Layers.txt'],
#  'learning': ['Other Layers.txt'],
#  'know': ['Recurrent Neural Networks.txt'],
#  'study': ['Recurrent Neural Networks.txt'],
#  'model': ['Recurrent Neural Networks.txt',
#   'Serial Layer.txt',
#   'Training.txt',
#   'Trax Neural Networks.txt'],
#  'ask': ['Recurrent Neural Networks.txt'],
#  'supposed': ['Recurrent Neural Networks.txt'],
#  'learnable': ['Recurrent Neural Networks.txt'],
#  'choose': ['Recurrent Neural Networks.txt'],
#  'every': ['Recurrent Neural Networks.txt'],
#  'previous': ['Recurrent Neural Networks.txt'],
#  'computations': ['Recurrent Neural Networks.txt', 'Trax Neural Networks.txt'],
#  'recortil': ['Recurrent Neural Networks.txt'],
#  'wz': ['Recurrent Neural Networks.txt'],
#  'advantages': ['Recurrent Neural Networks.txt', 'Trax Neural Networks.txt'],
#  'look': ['Recurrent Neural Networks.txt'],
#  'wꮵ': ['Recurrent Neural Networks.txt'],
#  'attempt': ['Recurrent Neural Networks.txt'],
#  'lot': ['Recurrent Neural Networks.txt', 'Traditional Language Models.txt'],
#  'w₂': ['Recurrent Neural Networks.txt',
#   'Traditional Language Models.txt',
#   'Traditional Language Models.txt'],
#  'relationships': ['Recurrent Neural Networks.txt'],
#  'words': ['Recurrent Neural Networks.txt', 'Traditional Language Models.txt'],
#  'similar': ['Recurrent Neural Networks.txt'],
#  'w₁': ['Recurrent Neural Networks.txt',
#   'Traditional Language Models.txt',
#   'Traditional Language Models.txt'],
#  'probabilities': ['Recurrent Neural Networks.txt'],
#  'ꮵ': ['Recurrent Neural Networks.txt'],
#  'called': ['Recurrent Neural Networks.txt'],
#  'respond': ['Recurrent Neural Networks.txt'],
#  'answer': ['Recurrent Neural Networks.txt'],
#  'trigram': ['Recurrent Neural Networks.txt'],
#  'nour': ['Recurrent Neural Networks.txt'],
#  'among': ['Recurrent Neural Networks.txt'],
#  'want': ['Recurrent Neural Networks.txt'],
#  'distant': ['Recurrent Neural Networks.txt',
#   'Traditional Language Models.txt'],
#  'compute': ['Serial Layer.txt'],
#  'entire': ['Serial Layer.txt'],
#  'arrangement': ['Serial Layer.txt'],
#  'serial': ['Serial Layer.txt',
#   'Serial Layer.txt',
#   'Trax Neural Networks.txt'],
#  'int': ['Serial Layer.txt'],
#  'activation': ['Serial Layer.txt'],
#  'inf': ['Serial Layer.txt'],
#  'composition': ['Serial Layer.txt'],
#  'sequence': ['Traditional Language Models.txt'],
#  'large': ['Traditional Language Models.txt'],
#  'game': ['Traditional Language Models.txt'],
#  'ws': ['Traditional Language Models.txt', 'Traditional Language Models.txt'],
#  'bigrams': ['Traditional Language Models.txt'],
#  'count': ['Traditional Language Models.txt'],
#  'le': ['Traditional Language Models.txt'],
#  'capture': ['Traditional Language Models.txt'],
#  '1₂': ['Traditional Language Models.txt'],
#  'w3': ['Traditional Language Models.txt', 'Traditional Language Models.txt'],
#  'ram': ['Traditional Language Models.txt'],
#  'need': ['Traditional Language Models.txt'],
#  'wy': ['Traditional Language Models.txt'],
#  'trigrams': ['Traditional Language Models.txt'],
#  'avize': ['Traditional Language Models.txt'],
#  'dependencies': ['Traditional Language Models.txt'],
#  'wi': ['Traditional Language Models.txt'],
#  'models': ['Traditional Language Models.txt'],
#  'saw': ['Traditional Language Models.txt', 'Traditional Language Models.txt'],
#  'aviz': ['Traditional Language Models.txt'],
#  'w2': ['Traditional Language Models.txt', 'Traditional Language Models.txt'],
#  'ur': ['Traditional Language Models.txt'],
#  'un': ['Traditional Language Models.txt'],
#  'ww2': ['Traditional Language Models.txt'],
#  'space': ['Traditional Language Models.txt'],
#  'foot': ['Traditional Language Models.txt'],
#  'vu': ['Traditional Language Models.txt'],
#  'traditional': ['Traditional Language Models.txt'],
#  'coumt': ['Traditional Language Models.txt'],
#  'u': ['Traditional Language Models.txt'],
#  'soccer': ['Traditional Language Models.txt'],
#  'w1': ['Traditional Language Models.txt'],
#  'grams': ['Traditional Language Models.txt'],
#  'language': ['Traditional Language Models.txt'],
#  'backpropagation': ['Training.txt'],
#  'back': ['Training.txt'],
#  'training': ['Training.txt', 'Training.txt'],
#  'easier': ['Training.txt'],
#  'grads': ['Training.txt'],
#  '6x': ['Training.txt'],
#  'returns': ['Training.txt'],
#  'grad_f': ['Training.txt'],
#  'much': ['Training.txt'],
#  '8x': ['Training.txt'],
#  'computing': ['Training.txt', 'Trax Neural Networks.txt'],
#  'grad': ['Training.txt'],
#  'gradients': ['Training.txt'],
#  'gradsgrad': ['Training.txt'],
#  'allows': ['Training.txt'],
#  'line': ['Training.txt'],
#  'gradient': ['Training.txt', 'Trax Neural Networks.txt'],
#  'loop': ['Training.txt'],
#  'descent': ['Training.txt'],
#  'alpha': ['Training.txt'],
#  '3x²': ['Training.txt'],
#  'sx': ['Training.txt'],
#  'cpus': ['Trax Neural Networks.txt'],
#  'define': ['Trax Neural Networks.txt'],
#  'computation': ['Trax Neural Networks.txt'],
#  'order': ['Trax Neural Networks.txt'],
#  'jjik': ['Trax Neural Networks.txt'],
#  'record': ['Trax Neural Networks.txt'],
#  'wil': ['Trax Neural Networks.txt'],
#  'run': ['Trax Neural Networks.txt'],
#  'netiv': ['Trax Neural Networks.txt'],
#  'tl': ['Trax Neural Networks.txt'],
#  'frameworks': ['Trax Neural Networks.txt'],
#  'etworks': ['Trax Neural Networks.txt'],
#  'softmax': ['Trax Neural Networks.txt'],
#  'gpus': ['Trax Neural Networks.txt'],
#  'parallel': ['Trax Neural Networks.txt'],
#  'x24': ['Trax Neural Networks.txt'],
#  'tensorflow': ['Trax Neural Networks.txt'],
#  'import': ['Trax Neural Networks.txt'],
#  'tpus': ['Trax Neural Networks.txt', 'Trax Neural Networks.txt'],
#  'negral': ['Trax Neural Networks.txt'],
#  'pytorch': ['Trax Neural Networks.txt'],
#  'fast': ['Trax Neural Networks.txt'],
#  'algebraic': ['Trax Neural Networks.txt'],
#  'jax': ['Trax Neural Networks.txt'],
#  'sigmoid': ['Trax Neural Networks.txt'],
#  'it': ['Trax Neural Networks.txt'],
#  'evaluation': ['Trax Neural Networks.txt'],
#  '11gl¹': ['Trax Neural Networks.txt'],
#  'ia': ['Trax Neural Networks.txt'],
#  'ral': ['Trax Neural Networks.txt'],
#  'network': ['Trax Neural Networks.txt'],
#  'benefits': ['Trax Neural Networks.txt'],
#  'trac': ['Trax Neural Networks.txt'],
#  'whijr': ['Trax Neural Networks.txt']}

# %%
loaded_dict["tweet"]
# Out:
# ['Neural Network for Sentiment Analysis.txt']
